# %%
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.flipkart.com/smart-watch-screenguards/pr?sid=ajy,vne,qic&offer=nb:mp:0586121203&marketplace=FLIPKART&restrictLocale=true&fm=personalisedRecommendation%2FC2&iid=R%3Ato%3Bpt%3Ahp%3Buid%3A4a51bb77-eee3-11ec-b3fb-038877adf8fe%3B.cid%3AS_F_N_ajy_vne_qic__o_nb_mp_0586121203__NONE_ALL%3Bnid%3Aajy_vne_qic_%3Bet%3AS%3Beid%3Aajy_vne_qic_%3Bmp%3AF%3Bct%3Ao%3B&ssid=r37fqborzk0000001655542033450&otracker=hp_reco_Trending%2BOffers_1_10.dealCard.OMU_cid%3AS_F_N_ajy_vne_qic__o_nb_mp_0586121203__NONE_ALL%3Bnid%3Aajy_vne_qic_%3Bet%3AS%3Beid%3Aajy_vne_qic_%3Bmp%3AF%3Bct%3Ao%3B_5&otracker1=hp_reco_WHITELISTED_personalisedRecommendation%2FC2_Trending%2BOffers_DESKTOP_HORIZONTAL_dealCard_cc_1_NA_view-all_5&cid=cid%3AS_F_N_ajy_vne_qic__o_nb_mp_0586121203__NONE_ALL%3Bnid%3Aajy_vne_qic_%3Bet%3AS%3Beid%3Aajy_vne_qic_%3Bmp%3AF%3Bct%3Ao%3B"

# %%
res = requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
ajith =BeautifulSoup(res.text)

# %%
ajith
# Out:
# <!DOCTYPE html>
# ...

# %%
watch = ajith.select('.s1Q9rs')

# %%
watch
# Out:
# [<a class="s1Q9rs" href="/raptag-edge-screen-guard-noise-colorfit-smartwatch-pro-3/p/itm42ff1fcf82e51?pid=ACCGAFT7K3GQP6G7&amp;lid=LSTACCGAFT7K3GQP6G7KZH9DP&amp;marketplace=FLIPKART&amp;store=ajy%2Fvne%2Fqic&amp;srno=b_1_1&amp;otracker=hp_reco_Trending%2BOffers_1_10.dealCard.OMU_cid%3AS_F_N_ajy_vne_qic__o_nb_mp_0586121203__NONE_ALL%3Bnid%3Aajy_vne_qic_%3Bet%3AS%3Beid%3Aajy_vne_qic_%3Bmp%3AF%3Bct%3Ao%3B_5&amp;otracker1=hp_reco_WHITELISTED_personalisedRecommendation%2FC2_Trending%2BOffers_DESKTOP_HORIZONTAL_dealCard_cc_1_NA_view-all_5&amp;fm=organic&amp;iid=566b2f58-16a9-47fa-9adf-54baeebc1218.ACCGAFT7K3GQP6G7.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=gelz8gusdc0000001655544202699" rel="noopener noreferrer" target="_blank" title="RapTag Edge To Edge Screen Guard for Noise Colorfit SmartWatch Pro 3 [ घड़ी शामिल नहीं है, यह केवल स्क्रीन गार्ड है ]">RapTag Edge To Edge Screen Guard for Noise Colorfit Sma...</a>,
# ...

# %%
Price = ajith.select('._30jeq3')

# %%
Price
# Out:
# [<div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
#  <div class="_30jeq3">₹99</div>,
# ...

# %%
discount = ajith.select('._3Ay6Sb span')

# %%
discount
# Out:
# [<span>90% off</span>,
#  <span>91% off</span>,
#  <span>91% off</span>,
#  <span>90% off</span>,
#  <span>90% off</span>,
#  <span>90% off</span>,
#  <span>92% off</span>,
#  <span>92% off</span>,
#  <span>92% off</span>,
#  <span>90% off</span>,
#  <span>92% off</span>,
#  <span>91% off</span>,
#  <span>92% off</span>,
#  <span>91% off</span>,
#  <span>88% off</span>,
#  <span>90% off</span>,
#  <span>92% off</span>,
#  <span>90% off</span>,
#  <span>90% off</span>,
#  <span>92% off</span>,
#  <span>90% off</span>,
#  <span>92% off</span>,
#  <span>90% off</span>,
#  <span>91% off</span>,
#  <span>92% off</span>,
#  <span>90% off</span>,
#  <span>92% off</span>,
#  <span>92% off</span>,
#  <span>92% off</span>,
#  <span>90% off</span>,
#  <span>92% off</span>,
#  <span>88% off</span>,
#  <span>92% off</span>,
#  <span>90% off</span>,
#  <span>92% off</span>,
#  <span>92% off</span>,
#  <span>92% off</span>,
#  <span>92% off</span>,
#  <span>92% off</span>,
#  <span>92% off</span>]

# %%
watch_name=[]

# %%
for item in watch:
    watch_name.append(item.text)

# %%
watch_name
# Out:
# ['RapTag Edge To Edge Screen Guard for Noise Colorfit Sma...',
#  'VPrime Edge To Edge Screen Guard for MX-HEALTHIB HIN02-...',
#  'VPrime Edge To Edge Screen Guard for LX-BETAMAX d13 wat...',
#  'RapTag Impossible Screen Guard for VND Noise Colorfit P...',
#  'RapTag Impossible Screen Guard for NNT Noisefit Pro 2 S...',
#  'VPrime Screen Guard for JGJ:-Realme smart Watch',
#  'VPrime Screen Guard for GTX Apple watch Series 1 42MM [...',
#  'RapTag Edge To Edge Screen Guard for [Transparent] CYXU...',
#  'RapTag Edge To Edge Screen Guard for Pii Fire Boltt Rin...',
#  'VPrime Edge To Edge Screen Guard for Noise Colorfit Sma...',
#  'VPrime Edge To Edge Screen Guard for Gionee Watch 5 Sma...',
#  'VPrime Edge To Edge Screen Guard for LX-HEALTHIB HIN02-...',
#  'VPrime Screen Guard for CROX Amazfit GTS 2 mini [ घड़ी ...',
#  'VPrime Edge To Edge Screen Guard for Dx-Vin e-Comfort86...',
#  'RapTag Screen Guard for GO Noise ColorFit Caliber Smart...',
# ...

# %%
Price_name=[]

# %%
for item in Price:
    Price_name.append(item.text)

# %%
Price_name
# Out:
# ['₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99',
#  '₹99']

# %%
discount_name=[]

# %%
for item in discount:
    discount_name.append(item.text)

# %%
discount_name
# Out:
# ['90% off',
#  '91% off',
#  '91% off',
#  '90% off',
#  '90% off',
#  '90% off',
#  '92% off',
#  '92% off',
#  '92% off',
#  '90% off',
#  '92% off',
#  '91% off',
#  '92% off',
#  '91% off',
#  '88% off',
#  '90% off',
#  '92% off',
#  '90% off',
#  '90% off',
#  '92% off',
#  '90% off',
#  '92% off',
#  '90% off',
#  '91% off',
#  '92% off',
#  '90% off',
#  '92% off',
#  '92% off',
#  '92% off',
#  '90% off',
#  '92% off',
#  '88% off',
#  '92% off',
#  '90% off',
#  '92% off',
#  '92% off',
#  '92% off',
#  '92% off',
#  '92% off',
#  '92% off']

# %%
ac = pd.DataFrame(watch_name,columns=["watch_name"])

# %%
ac
# Out:
#                                            watch_name
# 0   RapTag Edge To Edge Screen Guard for Noise Col...
# 1   VPrime Edge To Edge Screen Guard for MX-HEALTH...
# 2   VPrime Edge To Edge Screen Guard for LX-BETAMA...
# 3   RapTag Impossible Screen Guard for VND Noise C...
# 4   RapTag Impossible Screen Guard for NNT Noisefi...
# 5     VPrime Screen Guard for JGJ:-Realme smart Watch
# 6   VPrime Screen Guard for GTX Apple watch Series...
# 7   RapTag Edge To Edge Screen Guard for [Transpar...
# 8   RapTag Edge To Edge Screen Guard for Pii Fire ...
# 9   VPrime Edge To Edge Screen Guard for Noise Col...
# 10  VPrime Edge To Edge Screen Guard for Gionee Wa...
# 11  VPrime Edge To Edge Screen Guard for LX-HEALTH...
# 12  VPrime Screen Guard for CROX Amazfit GTS 2 min...
# 13  VPrime Edge To Edge Screen Guard for Dx-Vin e-...
# 14  RapTag Screen Guard for GO Noise ColorFit Cali...
# 15  VPrime Screen Guard for JRSM:-HEALTHIB HIN02-G...
# ...

# %%
ac['Price']=Price

# %%
ac
# Out:
#                                            watch_name  Price
# 0   RapTag Edge To Edge Screen Guard for Noise Col...  [₹99]
# 1   VPrime Edge To Edge Screen Guard for MX-HEALTH...  [₹99]
# 2   VPrime Edge To Edge Screen Guard for LX-BETAMA...  [₹99]
# 3   RapTag Impossible Screen Guard for VND Noise C...  [₹99]
# 4   RapTag Impossible Screen Guard for NNT Noisefi...  [₹99]
# 5     VPrime Screen Guard for JGJ:-Realme smart Watch  [₹99]
# 6   VPrime Screen Guard for GTX Apple watch Series...  [₹99]
# 7   RapTag Edge To Edge Screen Guard for [Transpar...  [₹99]
# 8   RapTag Edge To Edge Screen Guard for Pii Fire ...  [₹99]
# 9   VPrime Edge To Edge Screen Guard for Noise Col...  [₹99]
# 10  VPrime Edge To Edge Screen Guard for Gionee Wa...  [₹99]
# 11  VPrime Edge To Edge Screen Guard for LX-HEALTH...  [₹99]
# 12  VPrime Screen Guard for CROX Amazfit GTS 2 min...  [₹99]
# 13  VPrime Edge To Edge Screen Guard for Dx-Vin e-...  [₹99]
# ...

# %%
ac["discount"]=discount

# %%
ac
# Out:
#                                            watch_name  Price   discount
# 0   RapTag Edge To Edge Screen Guard for Noise Col...  [₹99]  [90% off]
# 1   VPrime Edge To Edge Screen Guard for MX-HEALTH...  [₹99]  [91% off]
# 2   VPrime Edge To Edge Screen Guard for LX-BETAMA...  [₹99]  [91% off]
# 3   RapTag Impossible Screen Guard for VND Noise C...  [₹99]  [90% off]
# 4   RapTag Impossible Screen Guard for NNT Noisefi...  [₹99]  [90% off]
# 5     VPrime Screen Guard for JGJ:-Realme smart Watch  [₹99]  [90% off]
# 6   VPrime Screen Guard for GTX Apple watch Series...  [₹99]  [92% off]
# 7   RapTag Edge To Edge Screen Guard for [Transpar...  [₹99]  [92% off]
# 8   RapTag Edge To Edge Screen Guard for Pii Fire ...  [₹99]  [92% off]
# 9   VPrime Edge To Edge Screen Guard for Noise Col...  [₹99]  [90% off]
# 10  VPrime Edge To Edge Screen Guard for Gionee Wa...  [₹99]  [92% off]
# 11  VPrime Edge To Edge Screen Guard for LX-HEALTH...  [₹99]  [91% off]
# ...

# %%
ac.to_csv("aji.csv")

# %%
ac["watch_name"]=ac["watch_name"].str.strip('<a class="s1Q9rs" href="//p/itm42ff1fcf82e51?pid=ACCGAFT7K3GQP6G7&amp;lid=LSTACCGAFT7K3GQP6G7KZH9DP&amp;marketplace=FLIPKART&amp;store=ajy%2Fvne%2Fqic&amp;srno=b_1_1&amp;otracker=hp_reco_Trending%2BOffers_1_10.dealCard.OMU_cid%3AS_F_N_ajy_vne_qic__o_nb_mp_0586121203__NONE_ALL%3Bnid%3Aajy_vne_qic_%3Bet%3AS%3Beid%3Aajy_vne_qic_%3Bmp%3AF%3Bct%3Ao%3B_5&amp;otracker1=hp_reco_WHITELISTED_personalisedRecommendation%2FC2_Trending%2BOffers_DESKTOP_HORIZONTAL_dealCard_cc_1_NA_view-all_5&amp;fm=organic&amp;iid=9552c5a5-0925-40a3-bc9e-4d9614e424d6.ACCGAFT7K3GQP6G7.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=f43okmkrww0000001655542178202" rel="noopener noreferrer" target="_blank" title=" [ घड़ी शामिल नहीं है, यह केवल स्क्रीन गार्ड है ]"></a>').astype(str)

# %%
ac
# Out:
#                                            watch_name  Price   discount
# 0                                                   u  [₹99]  [90% off]
# 1             VPrime Edge To Edge Screen Guard for MX  [₹99]  [91% off]
# 2     VPrime Edge To Edge Screen Guard for LX-BETAMAX  [₹99]  [91% off]
# 3                                          uard for V  [₹99]  [90% off]
# 4                                                   u  [₹99]  [90% off]
# 5                        VPrime Screen Guard for JGJ:  [₹99]  [90% off]
# 6                         VPrime Screen Guard for GTX  [₹99]  [92% off]
# 7                          uard for [Transparent] CYX  [₹99]  [92% off]
# 8                                                   u  [₹99]  [92% off]
# 9                       VPrime Edge To Edge Screen Gu  [₹99]  [90% off]
# 10                      VPrime Edge To Edge Screen Gu  [₹99]  [92% off]
# 11            VPrime Edge To Edge Screen Guard for LX  [₹99]  [91% off]
# ...

# %%
ac.to_csv("aji.csv")
